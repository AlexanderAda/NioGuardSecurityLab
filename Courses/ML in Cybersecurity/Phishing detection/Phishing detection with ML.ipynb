# %% [markdown]
# ## Clasification of phishng and benign URLs
# * Loading dataset from CSV file
# * Data exploration with 2D and 3D plots
# * Classification with KNN
# * Drawing a boundary between classes with KNN
# * Dimensionality reduction with PCA and t-SNE
# * Clustering with k-Means

# %%
# Load CSV
import pandas as pd
import numpy as np


filename = 'Examples - Phishing clasification2.csv'

# Specify the names of attributes if the header is not availabel in a CSV file 
#names = ['Registrar', 'Lifetime', 'Country', 'Class']

# Loading with NumPy
#raw_data = open(filename, 'rt')
#data = numpy.loadtxt(raw_data, delimiter=",")

# Loading with Pandas
data = pd.read_csv(filename)
print(data.shape)
#data
#data.dtypes

# Transforming 'object' data to 'categorical' to get numerical (ordinal numbers) representation
data['Registrar'] = data['Registrar'].astype('category')
data['Country'] = data['Country'].astype('category')
data['Protocol'] = data['Protocol'].astype('category')
data['Class'] = data['Class'].astype('category')

data['Registrar_code'] = data['Registrar'].cat.codes
data['Country_code'] = data['Country'].cat.codes
data['Protocol_code'] = data['Protocol'].cat.codes
data['Class_code'] = data['Class'].cat.codes

#data.dtypes
pd.options.display.max_rows=1000
data
#pd.options.display.max_rows=100
# Out:
# (202, 5)
#                                              Registrar  Lifetime  \
# 0                                              godaddy         2
# 1                                       XXLPOWER.CO.UA         1
# 2                                              godaddy         2
# 3                                    LOGINCOMPUTERS.IN         1
# 4                                              godaddy         1
# 5                                   REGISTER.COM, INC.         9
# 6                                              godaddy         2
# 7                       PSI-USA, INC. DBA DOMAIN ROBOT         3
# 8              PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         5
# 9              PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         4
# 10                              FASTNETINFORMATICS.COM         1
# 11                                      MINBSAPERU.COM         6
# 12                                         TINYURL.COM        16
# 13                                              TUCOWS         2
# 14                                       MYPAYPAAL.COM         1
# 15                                CONVERGYSEMPLEOS.COM         1
# 16                             NETWORK SOLUTIONS, LLC.         1
# 17                                     Namesco Limited         1
# 18                                         CONLOUW.COM         1
# 19                                       NAMESILO, LLC         1
# 20                  Webiq Domains Solutions Pvt. Ltd.          4
# 21                                          allegro.pl        18
# 22                                  Ascio Technologies         2
# 23                                BAGTHOSEBARGAINS.COM         1
# 24                                             godaddy         1
# 25                                             godaddy         1
# 26                                         IMOMANS.COM         1
# 27                                 orcadesmarine.co.uk         2
# 28                                            FBS INC.         1
# 29                                   EMINENCECOACH.COM         2
# 30                                          ALMODY.COM         1
# 31                                SUNDOWNVACATIONS.COM         1
# 32                                             godaddy         4
# 33                                             godaddy         3
# 34                                      COMITETUL.INFO         1
# 35                                             Godaddy         2
# 36                                             Godaddy         2
# 37                                SUNDOWNVACATIONS.COM         1
# 38                                          ALMODY.COM         1
# 39                                     FASTDOMAIN, INC         5
# 40                                     EVERYCITY.CO.UK         7
# 41                                   EMINENCECOACH.COM         2
# 42                                             home.pl         3
# 43                            HOLISTICHEALTH-GUIDE.COM         7
# 44                                                 NaN         1
# 45                                             godaddy         9
# 46                                             godaddy         9
# 47                                  DNC HOLDINGS, INC.         4
# 48                                             godaddy         1
# 49                                            enom.com         6
# 50                                          ALMODY.COM         1
# 51                                          eib.edu.bd         0
# 52                                            enom.com         4
# 53                                             godaddy         1
# 54                                              TUCOWS        16
# 55                                             godaddy        12
# 56                                             godaddy        14
# 57                                             godaddy         4
# 58                                       NAMESILO, LLC         1
# 59                                        LESPOWER.COM         5
# 60                                             godaddy         4
# 61                                              TUCOWS         4
# 62                                           lowicz.pl         3
# 63                                             godaddy         2
# 64                                             godaddy         2
# 65                                            enom.com         6
# 66                                      WEBFUSION LTD.         8
# 67                          casamentoparasempre.com.br         1
# 68                                            enom.com         6
# 69                          easyDNS Technologies, Inc.         3
# 70                                 MANGAVERDEBEACH.COM         2
# 71             PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         1
# 72                                             godaddy         1
# 73                                             godaddy         4
# 74                                             godaddy         3
# 75                   Akky (Una division de NIC Mexico)         3
# 76                                             godaddy         1
# 77                                             godaddy         5
# 78                                             godaddy         1
# 79                                            enom.com         1
# 80                                            enom.com        12
# 81                                             godaddy         7
# 82                                      WEBFUSION LTD.         8
# 83             PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         7
# 84                                      WEBFUSION LTD.         8
# 85             PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         1
# 86                                             godaddy         1
# 87                                             godaddy         1
# 88                                        REG-ACTIVE24         2
# 89                                             godaddy         4
# 90          HONG KONG TELECOMMUNICATIONS (HKT) LIMITED        12
# 91                          Comercial Gonalves e Rocha         7
# 92                                             godaddy         1
# 93                                             godaddy         1
# 94                                              TUCOWS         1
# 95                                             godaddy         1
# 96                                             godaddy         1
# 97                                             godaddy         6
# 98             PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         7
# 99                                             godaddy         1
# 100                                            godaddy         1
# 101                                            godaddy         2
# 102                                                NaN         1
# 103                                             TUCOWS        11
# 104                              TLDS, LLC DBA SRSPLUS         9
# 105                                            godaddy         1
# 106                                  WILD WEST DOMAINS         1
# 107                                            godaddy         1
# 108                              TLDS, LLC DBA SRSPLUS         9
# 109                                  WILD WEST DOMAINS         1
# 110                                            godaddy         4
# 111                           PUBLICDOMAINREGISTRY.COM         1
# 112                                          JOKER.COM         4
# 113                                      LAUNCHPAD.COM         0
# 114                               WhoisGuard Protected         0
# 115                                            godaddy         6
# 116                                            home.pl         5
# 117                                            godaddy         1
# 118                                            godaddy         1
# 119            PDR LTD. D/B/A PUBLICDOMAINREGISTRY.COM         3
# 120                                            godaddy         5
# 121                Lunar Pages - The Magi Organization         1
# 122                                         CloudFlare         1
# 123                                       CyrusOne LLC         5
# 124                                             TUCOWS         6
# 125                                            home.pl         8
# 126                                Hetzner Online GmbH         4
# 127                                            home.pl         1
# 128                                                NaN         0
# 129                        TLD REGISTRAR SOLUTIONS LTD         1
# 130                                    Andrew Florides         1
# 131                  EUROPEAN PROJECTS GROUP SP.Z O.O.        13
# 132                                           SaudiNIC         5
# 133                                           enom.com         4
# 134                 Wild West Domains, LLC (R120-LROR)         1
# 135                                      LAUNCHPAD.COM         3
# 136                               CRAZY DOMAINS FZ-LLC         3
# 137                                            godaddy         4
# 138                                  1 & 1 INTERNET AG         2
# 139                                            godaddy         1
# 140                                          mclink.it        14
# 141                                            godaddy         1
# 142                                            godaddy         1
# 143                                            godaddy         1
# 144                                 Websitewelcome.com         1
# 145                                   mysitehosted.com         0
# 146                                            jump.ro         2
# 147                           PublicDomainRegistry.com         1
# 148                                  Registrar IANA ID         1
# 149                                             TUCOWS         3
# 150                                wildwestdomains.com         7
# 151                           PublicDomainRegistry.com         1
# 152                                        registro.br         1
# 153                                            godaddy         6
# 154                                          SE Direkt        14
# 155                                   MARKMONITOR INC.         7
# 156                                   MARKMONITOR INC.        12
# 157                                   KEY-SYSTEMS GMBH        12
# 158                                            NL61-IS        10
# 159                                 Local Register Inc        13
# 160                                        EURODNS S.A        17
# 161                                        EURODNS S.A        10
# 162                                   KEY-SYSTEMS GMBH        10
# 163                                        EURODNS S.A        16
# 164                                        EURODNS S.A        15
# 165                                    DOMAIN.COM, LLC        17
# 166                                        EURODNS S.A        15
# 167                                 DNC HOLDINGS, INC.        17
# 168                                        EURODNS S.A        16
# 169                                        EURODNS S.A        25
# 170                        CSC CORPORATE DOMAINS, INC.        22
# 171                              FABULOUS.COM PTY LTD.        13
# 172                                          Loopia AB         2
# 173                                   GODADDY.COM, LLC        11
# 174                                        EURODNS S.A        18
# 175                                NETWORKING4ALL B.V.        18
# 176                                        GOOGLE INC.        23
# 177                                        EURODNS S.A         4
# 178                                   GODADDY.COM, LLC         8
# 179                                   GODADDY.COM, LLC        16
# 180                                   MARKMONITOR INC.        16
# 181                                          ENOM, INC         7
# 182                                     NAME.COM, INC.        22
# 183                                          GANDI SAS        12
# 184                                   GODADDY.COM, LLC         7
# 185                             WILD WEST DOMAINS, LLC        10
# 186                                   MARKMONITOR INC.        20
# 187                                   MARKMONITOR INC.        16
# 188                                        EURODNS S.A        16
# 189                                   GODADDY.COM, LLC        11
# 190                                          ENOM, INC        13
# 191                             NETWORK SOLUTIONS, LLC        19
# 192                                   MARKMONITOR INC.        23
# 193                                   Melbourne IT Ltd         8
# 194                                          GANDI SAS         7
# 195                        CSC CORPORATE DOMAINS, INC.        34
# 196                              FABULOUS.COM PTY LTD.        23
# 197  Vitalwerks Internet Solutions, LLC DBA No-IP (...        14
# 198                                      Onlinenic Inc         5
# 199                                       TUCOWS, INC.         7
# 200                             NETWORK SOLUTIONS, LLC         6
# 201                                                USA         2
#
#             Country Protocol     Class  Registrar_code  Country_code  \
# 0                US     http  phishing              84            28
# 1               NaN     http  phishing              78            -1
# 2               NaN     http  phishing              84            -1
# 3                US     http  phishing              37            28
# 4                US     http  phishing              84            28
# 5                US     http  phishing              59            28
# 6               NaN     http  phishing              84            -1
# 7           Ireland     http  phishing              55            12
# 8             India     http  phishing              54            11
# 9                US     http  phishing              54            28
# 10              NaN     http  phishing              23            -1
# 11              NaN     http  phishing              43            -1
# 12              NaN     http  phishing              64            -1
# 13               US     http  phishing              67            28
# 14               CA     http  phishing              44             3
# 15              NaN     http  phishing               8            -1
# 16           France     http  phishing              49             8
# 17               UK     http  phishing              52            27
# 18              NaN     http  phishing               7            -1
# 19            India     http  phishing              47            11
# 20            India     http  phishing              74            11
# 21               US    https  phishing              79            28
# 22               CZ     http  phishing               4             4
# 23               US    https  phishing               5            28
# 24              NaN     http  phishing              84            -1
# 25               US     http  phishing              84            28
# 26               US     http  phishing              32            28
# 27           France     http  phishing              90             8
# 28           Turkey     http  phishing              24            26
# 29              NaN     http  phishing              16            -1
# 30               US     http  phishing               1            28
# 31               US     http  phishing              62            28
# 32      Netherlands     http  phishing              84            19
# 33               US     http  phishing              84            28
# 34      Netherlands     http  phishing               6            19
# 35           Canada     http  phishing              28             5
# 36               US     http  phishing              28            28
# 37               US     http  phishing              62            28
# 38               US     http  phishing               1            28
# 39               US     http  phishing              22            28
# 40               US     http  phishing              20            28
# 41               US     http  phishing              16            28
# 42           Poland    https  phishing              85            20
# 43            India     http  phishing              29            11
# 44               US     http  phishing              -1            28
# 45               US     http  phishing              84            28
# 46               US     http  phishing              84            28
# 47               US     http  phishing              14            28
# 48               US     http  phishing              84            28
# 49               US     http  phishing              83            28
# 50               US     http  phishing               1            28
# 51               US     http  phishing              82            28
# 52              NaN     http  phishing              83            -1
# 53               US     http  phishing              84            28
# 54               US     http  phishing              67            28
# 55               US     http  phishing              84            28
# 56               US     http  phishing              84            28
# 57          Germany     http  phishing              84             9
# 58       Bangladesh     http  phishing              47             2
# 59               US     http  phishing              36            28
# 60              NaN     http  phishing              84            -1
# 61               CA     http  phishing              67             3
# 62           Poland     http  phishing              87            20
# 63               US     http  phishing              84            28
# 64               US     http  phishing              84            28
# 65               US     http  phishing              83            28
# 66               UK     http  phishing              71            27
# 67               US     http  phishing              80            28
# 68               US     http  phishing              83            28
# 69               US     http  phishing              81            28
# 70               US     http  phishing              41            28
# 71               US     http  phishing              54            28
# 72               US     http  phishing              84            28
# 73          Germany     http  phishing              84             9
# 74              NaN     http  phishing              84            -1
# 75           Mexica     http  phishing               2            15
# 76               US     http  phishing              84            28
# 77               US     http  phishing              84            28
# 78               US     http  phishing              84            28
# 79               US     http  phishing              83            28
# 80               US     http  phishing              83            28
# 81               US     http  phishing              84            28
# 82               UK     http  phishing              71            27
# 83               US     http  phishing              54            28
# 84               UK     http  phishing              71            27
# 85               US     http  phishing              54            28
# 86               US     http  phishing              84            28
# 87               US     http  phishing              84            28
# 88   Czech Republic     http  phishing              58             7
# 89          Germany     http  phishing              84             9
# 90        Hong Kong     http  phishing              30            10
# 91               US     http  phishing              12            28
# 92               US     http  phishing              84            28
# 93               US     http  phishing              84            28
# 94     South Africa     http  phishing              67            25
# 95            India     http  phishing              84            11
# 96      Netherlands     http  phishing              84            19
# 97               US     http  phishing              84            28
# 98            India     http  phishing              54            11
# 99               US     http  phishing              84            28
# 100              US     http  phishing              84            28
# 101              US     http  phishing              84            28
# 102              US     http  phishing              -1            28
# 103              UK     http  phishing              67            27
# 104              US     http  phishing              66            28
# 105              US     http  phishing              84            28
# 106              US     http  phishing              72            28
# 107              US     http  phishing              84            28
# 108          Canada     http  phishing              66             5
# 109              US     http  phishing              72            28
# 110         Germany     http  phishing              84             9
# 111         Murrica     http  phishing              56            16
# 112         Murrica     http  phishing              33            16
# 113         Murrica     http  phishing              35            16
# 114         Murrica     http  phishing              76            16
# 115         Murrica     http  phishing              84            16
# 116          Poland     http  phishing              85            20
# 117              US     http  phishing              84            28
# 118              US    https  phishing              84            28
# 119              US     http  phishing              54            28
# 120              US     http  phishing              84            28
# 121              US     http  phishing              40            28
# 122              US     http  phishing              11            28
# 123              US     http  phishing              13            28
# 124              US     http  phishing              67            28
# 125          Poland    https  phishing              85            20
# 126          Russia     http  phishing              31            22
# 127          Poland    https  phishing              85            20
# 128           Chile     http  phishing              -1             6
# 129              US     http  phishing              65            28
# 130              UK     http  phishing               3            27
# 131          Poland     http  phishing              19            20
# 132              US     http  phishing              63            28
# 133              US     http  phishing              83            28
# 134       Singapore     http  phishing              77            24
# 135              US     http  phishing              35            28
# 136       Australia     http  phishing               9             1
# 137         Germany     http  phishing              84             9
# 138         Germany     http  phishing               0             9
# 139         Murrica     http  phishing              84            16
# 140           Italy     http  phishing              88            13
# 141         Murrica     http  phishing              84            16
# 142         Murrica     http  phishing              84            16
# 143         Murrica     http  phishing              84            16
# 144         Murrica     http  phishing              75            16
# 145         Murrica     http  phishing              89            16
# 146         Romaina     http  phishing              86            21
# 147           India     http  phishing              57            11
# 148         Murrica     http  phishing              60            16
# 149         Murrica     http  phishing              67            16
# 150         Murrica     http  phishing              92            16
# 151         Murrica     http  phishing              57            16
# 152         Murrica     http  phishing              91            16
# 153         Murrica     http  phishing              84            16
# 154              SE    https    benign              61            23
# 155              SE    https    benign              42            23
# 156              SE    https    benign              42            23
# 157              SE    https    benign              34            23
# 158              US    https    benign              51            28
# 159              SE    https    benign              38            23
# 160              LU    https    benign              18            14
# 161              LU    https    benign              18            14
# 162              NZ    https    benign              34            18
# 163              LU    https    benign              18            14
# 164              LU    https    benign              18            14
# 165              US    https    benign              15            28
# 166              LU    https    benign              18            14
# 167              US    https    benign              14            28
# 168              LU    https    benign              18            14
# 169              LU    https    benign              18            14
# 170              US    https    benign              10            28
# 171              AU    https    benign              21             0
# 172              SE    https    benign              39            23
# 173              US    https    benign              26            28
# 174              LU    https    benign              18            14
# 175              CZ    https    benign              50             4
# 176              NZ    https    benign              27            18
# 177              LU    https    benign              18            14
# 178              US    https    benign              26            28
# 179              US    https    benign              26            28
# 180              US    https    benign              42            28
# 181              US    https    benign              17            28
# 182              US    https    benign              46            28
# 183              US    https    benign              25            28
# 184              US    https    benign              26            28
# 185              US    https    benign              73            28
# 186              AU    https    benign              42             0
# 187              US    https    benign              42            28
# 188              LU    https    benign              18            14
# 189              US    https    benign              26            28
# 190              NL    https    benign              17            17
# 191          Canada    https    benign              48             5
# 192              US    https    benign              42            28
# 193              US    https    benign              45            28
# 194              US    https    benign              25            28
# 195              US    https    benign              10            28
# 196              US    https    benign              21            28
# 197          Canada    https    benign              70             5
# 198              US    https    benign              53            28
# 199              US    https    benign              68            28
# 200              US    https    benign              48            28
# 201              US    https    benign              69            28
#
#      Protocol_code  Class_code
# 0                0           1
# 1                0           1
# 2                0           1
# 3                0           1
# 4                0           1
# 5                0           1
# 6                0           1
# 7                0           1
# 8                0           1
# 9                0           1
# 10               0           1
# 11               0           1
# 12               0           1
# 13               0           1
# 14               0           1
# 15               0           1
# 16               0           1
# 17               0           1
# 18               0           1
# 19               0           1
# 20               0           1
# 21               1           1
# 22               0           1
# 23               1           1
# 24               0           1
# 25               0           1
# 26               0           1
# 27               0           1
# 28               0           1
# 29               0           1
# 30               0           1
# 31               0           1
# 32               0           1
# 33               0           1
# 34               0           1
# 35               0           1
# 36               0           1
# 37               0           1
# 38               0           1
# 39               0           1
# 40               0           1
# 41               0           1
# 42               1           1
# 43               0           1
# 44               0           1
# 45               0           1
# 46               0           1
# 47               0           1
# 48               0           1
# 49               0           1
# 50               0           1
# 51               0           1
# 52               0           1
# 53               0           1
# 54               0           1
# 55               0           1
# 56               0           1
# 57               0           1
# 58               0           1
# 59               0           1
# 60               0           1
# 61               0           1
# 62               0           1
# 63               0           1
# 64               0           1
# 65               0           1
# 66               0           1
# 67               0           1
# 68               0           1
# 69               0           1
# 70               0           1
# 71               0           1
# 72               0           1
# 73               0           1
# 74               0           1
# 75               0           1
# 76               0           1
# 77               0           1
# 78               0           1
# 79               0           1
# 80               0           1
# 81               0           1
# 82               0           1
# 83               0           1
# 84               0           1
# 85               0           1
# 86               0           1
# 87               0           1
# 88               0           1
# 89               0           1
# 90               0           1
# 91               0           1
# 92               0           1
# 93               0           1
# 94               0           1
# 95               0           1
# 96               0           1
# 97               0           1
# 98               0           1
# 99               0           1
# 100              0           1
# 101              0           1
# 102              0           1
# 103              0           1
# 104              0           1
# 105              0           1
# 106              0           1
# 107              0           1
# 108              0           1
# 109              0           1
# 110              0           1
# 111              0           1
# 112              0           1
# 113              0           1
# 114              0           1
# 115              0           1
# 116              0           1
# 117              0           1
# 118              1           1
# 119              0           1
# 120              0           1
# 121              0           1
# 122              0           1
# 123              0           1
# 124              0           1
# 125              1           1
# 126              0           1
# 127              1           1
# 128              0           1
# 129              0           1
# 130              0           1
# 131              0           1
# 132              0           1
# 133              0           1
# 134              0           1
# 135              0           1
# 136              0           1
# 137              0           1
# 138              0           1
# 139              0           1
# 140              0           1
# 141              0           1
# 142              0           1
# 143              0           1
# 144              0           1
# 145              0           1
# 146              0           1
# 147              0           1
# 148              0           1
# 149              0           1
# 150              0           1
# 151              0           1
# 152              0           1
# 153              0           1
# 154              1           0
# 155              1           0
# 156              1           0
# 157              1           0
# 158              1           0
# 159              1           0
# 160              1           0
# 161              1           0
# 162              1           0
# 163              1           0
# 164              1           0
# 165              1           0
# 166              1           0
# 167              1           0
# 168              1           0
# 169              1           0
# 170              1           0
# 171              1           0
# 172              1           0
# 173              1           0
# 174              1           0
# 175              1           0
# 176              1           0
# 177              1           0
# 178              1           0
# 179              1           0
# 180              1           0
# 181              1           0
# 182              1           0
# 183              1           0
# 184              1           0
# 185              1           0
# 186              1           0
# 187              1           0
# 188              1           0
# 189              1           0
# 190              1           0
# 191              1           0
# 192              1           0
# 193              1           0
# 194              1           0
# 195              1           0
# 196              1           0
# 197              1           0
# 198              1           0
# 199              1           0
# 200              1           0
# 201              1           0

# %%
X = data[['Registrar_code', 'Lifetime', 'Country_code', 'Protocol_code']].values   #Feature Matrix
y = data['Class_code'].values          #Target Variable

feature_names = data[['Registrar_code', 'Lifetime', 'Country_code', 'Protocol_code']].columns.values
#print(feature_names)
target_names = data['Class'].cat.categories
country_names = data['Country'].cat.categories
registrar_names = data['Registrar'].cat.categories
protocol_names = data['Protocol'].cat.categories
#print(target_names, country_names, registrar_names)

# %%
import matplotlib.pyplot as plt

x_index = 1
y_index = 3

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: target_names[int(i)])
plt.scatter(X[:, x_index], X[:, y_index], c=y, cmap=plt.cm.get_cmap('Paired', 2))
plt.colorbar(ticks=[0, 1], format=formatter)
plt.clim(-0.5, 1.5)
plt.xlabel(feature_names[x_index])
plt.ylabel(feature_names[y_index]);
plt.show()

# %%
 from mpl_toolkits.mplot3d import Axes3D
    
fig = plt.figure(1, figsize=(10, 8))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, 1, 1], elev=30, azim=100)
ax.scatter(X[:, 1], X[:, 2], X[:, 3], lw=2, c=y, cmap='Paired')
ax.set_xlabel(feature_names[1])
ax.set_ylabel(feature_names[2]);
ax.set_zlabel(feature_names[3]);
plt.show()

# %%
from sklearn import neighbors

# create the model
knn = neighbors.KNeighborsClassifier(n_neighbors=5)

# fit the model
knn.fit(X, y)

# call the "predict" method:
registrar_code = 48
lifetime = 2
country_code = 28 
protocol_code = 1

result = knn.predict([[registrar_code, lifetime, country_code, protocol_code],])
#print(target_names)
print(result, target_names[result[0]], ": ", registrar_names[registrar_code], lifetime, country_names[country_code], protocol_names[protocol_code] )
# Out:
# [1] phishing :  NETWORK SOLUTIONS, LLC 2 US https

# %%
from matplotlib.colors import ListedColormap

n_neighbors = 5
h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['cyan', 'red'])
cmap_bold = ListedColormap(['blue', 'orange'])

# Get '1: Lifetime' and '2: Country' attributes only 
x_index = 1
y_index = 2
X2 = X[:,[x_index, y_index]] 

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    knn = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    knn.fit(X2, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X2[:, 0].min() - 1, X2[:, 0].max() + 1
    y_min, y_max = X2[:, 1].min() - 1, X2[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X2[:, 0], X2[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("2-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))
    plt.xlabel(feature_names[x_index])
    plt.ylabel(feature_names[y_index]);

plt.show()

# %% [markdown]
# ### Dimensionality reduction with PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
X_reduced = pca.transform(X)
print("Reduced dataset shape:", X_reduced.shape)
# Out:
# Reduced dataset shape: (202, 2)

# %%
# PCA only
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap='Paired')

print("Meaning of the components:")
for component in pca.components_:
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component, feature_names)))
# Out:
# Meaning of the components:
# -0.998 x Registrar_code + 0.065 x Lifetime + -0.022 x Country_code + 0.006 x Protocol_code
# 0.020 x Registrar_code + -0.035 x Lifetime + -0.999 x Country_code + -0.005 x Protocol_code

# %% [markdown]
# ### Dimensionality reduction with t-SNE

# %%
from sklearn.manifold import TSNE
X_reduced2 = TSNE(n_components=2).fit_transform(X)
# PCA + t-SNE
X_reduced3 = TSNE(n_components=2).fit_transform(X_reduced)
print("Reduced dataset shape:", X_reduced3.shape)
# Out:
# Reduced dataset shape: (202, 2)

# %%
# t-SNE only
plt.scatter(X_reduced2[:, 0], X_reduced2[:, 1], c=y, cmap='Paired')

# %%
# PCA + t-SNE
plt.scatter(X_reduced3[:, 0], X_reduced3[:, 1], c=y, cmap='Paired')

# %% [markdown]
# ### Clustering: K-means

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=2, random_state=0) # Fixing the RNG in kmeans
k_means.fit(X)
y_pred = k_means.predict(X)

plt.scatter(X_reduced2[:, 0], X_reduced2[:, 1], c=y_pred, cmap='Paired');

# %%
TP = 0
TN = 0
FP = 0
FN = 0

for i in range (0, len(y)):
    #print(i, ":", y[i])
    if (y[i] == 1): # Positive
        if (y[i] == y_pred[i]):
            TP+=1
        else:
            FN+=1
    else:
        if (y[i] == y_pred[i]):
            TN+=1
        else:
            FP+=1

    
print("TP =", TP, "TN =", TN, "FP =", FP, "FN =", FN) 

TPR = TP / (TP+FN)
TNR = TN / (TN+FP)
FPR = FP / (FP+TN)
FNR = FN / (TP+FN)
PPV = (TP+TN) / (TP+TN+FP+FN)
NPV = TN / (TN+FN)
Fmeasure = 2*PPV*TPR / (PPV + TPR)

print("TPR =", TPR, "TNR =", TNR, "FPR =", FPR, "FNR =", FNR, "PPV =", PPV, "NPV =", NPV, "F-measure =", Fmeasure)
# Out:
# TP = 110 TN = 41 FP = 7 FN = 44
# TPR = 0.7142857142857143 TNR = 0.8541666666666666 FPR = 0.14583333333333334 FNR = 0.2857142857142857 PPV = 0.7475247524752475 NPV = 0.4823529411764706 F-measure = 0.7305273343009193
